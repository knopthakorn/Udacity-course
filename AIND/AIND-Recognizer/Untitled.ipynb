# %%
import matplotlib.pyplot as plt

model_label = ('CV', 'BIC', 'DIC')
n_groups = len(model_label)

times_FISH      = (0.03646962500351947, 0.791462364999461, 1.397983803995885)
times_BOOK      = (6.9508690040092915, 3.8048021380091086, 7.016891577994102)
times_VEGETABLE = (2.871879832004197, 1.383324206006364, 5.393151532000047) 
times_FUTURE    = (6.758548281999538, 3.9538937830075156, 7.1689599030069076) 
times_JOHN      = (69.27704555199307, 32.801342638995266, 35.446890435996465)

states_FISH      = (2, 5, 3)
states_BOOK      = (6, 8, 15)
states_VEGETABLE = (2, 9, 15) 
states_FUTURE    = (2, 9, 15) 
states_JOHN      = (12, 14, 15)

index = np.arange(n_groups)
bar_width = 0.15
opacity = 0.8

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)
fig.tight_layout()

ax1 = plt.subplot(2, 1, 1)
plt.bar(index, 
        times_FISH, 
        bar_width,
        alpha=opacity,
        color='b',
        label='FISH')

plt.bar(index + bar_width, 
        times_BOOK, 
        bar_width,
        alpha=opacity,
        color='g',
        label='BOOK')

plt.bar(index + (2 * bar_width), 
        times_VEGETABLE, 
        bar_width,
        alpha=opacity,
        color='c',
        label='VEGETABLE')

plt.bar(index + (3 * bar_width), 
        states_FUTURE,
        bar_width,
        alpha=opacity,
        color='y',
        label='FUTURE')

plt.bar(index + (4 * bar_width), 
        times_JOHN,
        bar_width,
        alpha=opacity,
        color='m',
        label='JOHN')

plt.title('Word training times')
plt.ylabel('Time (s)')
plt.xticks(index + bar_width, model_label)
ax1.legend(loc='upper center', bbox_to_anchor=(1.15,1.05),
          ncol=1)


ax2 = plt.subplot(2, 1, 2)
fig.tight_layout()
fig.tight_layout()
fig.tight_layout()
fig.tight_layout()
plt.subplots_adjust(bottom = 0.01)
plt.bar(index, 
        states_FISH, 
        bar_width,
        alpha=opacity,
        color='b',
        label='FISH')

plt.bar(index + bar_width, 
        states_BOOK,
        bar_width,
        alpha=opacity,
        color='g',
        label='BOOK')

plt.bar(index + (2 * bar_width), 
        states_VEGETABLE, 
        bar_width,
        alpha=opacity,
        color='c',
        label='VEGETABLE')

plt.bar(index + (3 * bar_width), 
        states_FUTURE, 
        bar_width,
        alpha=opacity,
        color='y',
        label='FUTURE')

plt.bar(index + (4 * bar_width), 
        states_JOHN,
        bar_width,
        alpha=opacity,
        color='m',
        label='JOHN')


plt.title('Word training states')
plt.ylabel('States')
plt.xlabel('Model Selector')
plt.xticks(index + bar_width, model_label)


plt.show()

# %%
import matplotlib.pyplot as plt

model_label = ('CV', 'BIC', 'DIC')
n_groups = len(model_label)

times_FISH      = (0.03646962500351947, 0.791462364999461, 1.397983803995885)
times_BOOK      = (6.9508690040092915, 3.8048021380091086, 7.016891577994102)
times_VEGETABLE = (2.871879832004197, 1.383324206006364, 5.393151532000047) 
times_FUTURE    = (6.758548281999538, 3.9538937830075156, 7.1689599030069076) 
times_JOHN      = (69.27704555199307, 32.801342638995266, 35.446890435996465)

states_FISH      = (2, 5, 3)
states_BOOK      = (6, 8, 15)
states_VEGETABLE = (2, 9, 15) 
states_FUTURE    = (2, 9, 15) 
states_JOHN      = (12, 14, 15)

index = np.arange(n_groups)
bar_width = 0.15
opacity = 0.8

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)
fig.tight_layout()

ax1 = plt.subplot(2, 1, 1)
plt.bar(index, 
        times_FISH, 
        bar_width,
        alpha=opacity,
        color='b',
        label='FISH')

plt.bar(index + bar_width, 
        times_BOOK, 
        bar_width,
        alpha=opacity,
        color='g',
        label='BOOK')

plt.bar(index + (2 * bar_width), 
        times_VEGETABLE, 
        bar_width,
        alpha=opacity,
        color='c',
        label='VEGETABLE')

plt.bar(index + (3 * bar_width), 
        states_FUTURE,
        bar_width,
        alpha=opacity,
        color='y',
        label='FUTURE')

plt.bar(index + (4 * bar_width), 
        times_JOHN,
        bar_width,
        alpha=opacity,
        color='m',
        label='JOHN')

plt.title('Word training times')
plt.ylabel('Time (s)')
plt.xticks(index + bar_width, model_label)
ax1.legend(loc='upper center', bbox_to_anchor=(1.15,1.05),
          ncol=1)


ax2 = plt.subplot(2, 1, 2)
fig.tight_layout()
fig.tight_layout()
fig.tight_layout()
fig.tight_layout()
plt.subplots_adjust(bottom = 0.01)
plt.bar(index, 
        states_FISH, 
        bar_width,
        alpha=opacity,
        color='b',
        label='FISH')

plt.bar(index + bar_width, 
        states_BOOK,
        bar_width,
        alpha=opacity,
        color='g',
        label='BOOK')

plt.bar(index + (2 * bar_width), 
        states_VEGETABLE, 
        bar_width,
        alpha=opacity,
        color='c',
        label='VEGETABLE')

plt.bar(index + (3 * bar_width), 
        states_FUTURE, 
        bar_width,
        alpha=opacity,
        color='y',
        label='FUTURE')

plt.bar(index + (4 * bar_width), 
        states_JOHN,
        bar_width,
        alpha=opacity,
        color='m',
        label='JOHN')


plt.title('Word training states')
plt.ylabel('States')
plt.xlabel('Model Selector')
plt.xticks(index + bar_width, model_label)


plt.show()
